# %%
from pathlib import Path
import tempfile
import tarfile
import zstandard  
import urllib.request

import os
from glob import iglob

import json
from collections import defaultdict
import numpy as np
import pandas as pd

# %%
for x in range(0,1):
    urllib.request.urlretrieve(f"https://data.metabrainz.org/pub/musicbrainz/acousticbrainz/dumps/acousticbrainz-highlevel-json-20220623/acousticbrainz-highlevel-json-20220623-{x}.tar.zst"
                           ,f"/Users/ryanlnewbury/Downloads/acousticbrainz-highlevel-json-20220623-{x}.tar.zst")

# %%
#extract zst files function
# from https://gist.github.com/scivision/ad241e9cf0474e267240e196d7545eca
def extract_zst(archive: Path, out_path: Path):
    """extract .zst file
    works on Windows, Linux, MacOS, etc.
    
    Parameters
    ----------
    archive: pathlib.Path or str
      .zst file to extract
    out_path: pathlib.Path or str
      directory to extract files and directories to
    """

    archive = Path(archive).expanduser()
    out_path = Path(out_path).expanduser().resolve()
    # need .resolve() in case intermediate relative dir doesn't exist

    dctx = zstandard.ZstdDecompressor()

    with tempfile.TemporaryFile(suffix=".tar") as ofh:
        with archive.open("rb") as ifh:
            dctx.copy_stream(ifh, ofh)
        ofh.seek(0)
        with tarfile.open(fileobj=ofh) as z:
            z.extractall(out_path)

# %%
#local variables to file path, set as needed
for x in range(0,1):
    path_to_zst = f"/Users/ryanlnewbury/Downloads/acousticbrainz-highlevel-json-20220623-{x}.tar.zst"
    path_to_zst_extract = "/Users/ryanlnewbury/Downloads/highlevel"
    extract_zst(path_to_zst,
                path_to_zst_extract)

# %%
#creates directory route for every file in database
local_path = "/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel"
rootdir_glob = local_path + "/**/*"
# This will return absolute paths
file_list = [f for f in iglob(rootdir_glob, recursive=True) if os.path.isfile(f)]

# %%
#list of directories
file_list[:20]
# Out:
# ['/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619f63d9-9303-431b-b413-1681b49ae1f7-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619f60fa-b680-4735-a635-fc0f03715227-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619632d3-d916-49ad-8ddb-a27fcd0c2bad-1.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6192144b-0984-45bb-978a-9bdaa6fa13e9-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61978cc9-fcd1-4493-8ac7-a523d7853a52-2.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619ee3de-edef-4370-9373-02d90b1ccbb7-3.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6198c470-0f53-4043-8c96-cc81bee7ae40-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619d535a-b2b4-4e16-804c-e256f60a0267-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619aa0ff-588d-4764-a7b8-25d5ec3f287f-1.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6192fab3-88fe-4255-8079-f5c515391ce3-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61928cc7-9a42-4726-8f17-02d806ae7b4e-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619f9a63-bca6-4d2c-a121-043ef9129212-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61959535-0a81-4aac-ba6a-6c1837a1abc0-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6197eed5-42a7-4af0-8e03-25165ebc50d6-6.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619aae21-7a22-4336-915a-8bb3e3a34690-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619fdb9e-32cc-4fb5-b4b8-48d738f9ea02-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6199daf3-1d69-4a27-84bf-c456ccf521fe-7.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61983e0d-33f7-4d29-b5db-641837ac8ee8-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619c913b-975c-404c-bcbb-dfde093f6cd8-1.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619f18ad-b7c8-4b0e-826e-585de75b33f8-2.json']

# %%
#example json
f = open(file_list[0])
data = json.load(f)
data
# Out:
# {'highlevel': {'danceability': {'all': {'danceable': 0.180879756808,
#     'not_danceable': 0.819120228291},
#    'probability': 0.819120228291,
#    'value': 'not_danceable',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'gender': {'all': {'female': 0.345933228731, 'male': 0.654066741467},
#    'probability': 0.654066741467,
#    'value': 'male',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_dortmund': {'all': {'alternative': 0.017582796514,
#     'blues': 0.00265991478227,
#     'electronic': 0.967449188232,
#     'folkcountry': 0.00742371566594,
#     'funksoulrnb': 0.000294890458463,
#     'jazz': 0.00140640779864,
#     'pop': 0.000437961134594,
#     'raphiphop': 0.000112504334538,
#     'rock': 0.00263261166401},
#    'probability': 0.967449188232,
#    'value': 'electronic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_electronic': {'all': {'ambient': 0.280793100595,
#     'dnb': 0.0171333327889,
#     'house': 0.380855232477,
#     'techno': 0.0194362644106,
#     'trance': 0.30178207159},
#    'probability': 0.380855232477,
#    'value': 'house',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_rosamerica': {'all': {'cla': 0.00627187639475,
#     'dan': 0.136158540845,
#     'hip': 0.0241488739848,
#     'jaz': 0.0693898648024,
#     'pop': 0.292200863361,
#     'rhy': 0.430979788303,
#     'roc': 0.0321437306702,
#     'spe': 0.00870644766837},
#    'probability': 0.430979788303,
#    'value': 'rhy',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_tzanetakis': {'all': {'blu': 0.0620671063662,
#     'cla': 0.034474901855,
#     'cou': 0.103433981538,
#     'dis': 0.0620971247554,
#     'hip': 0.15527240932,
#     'jaz': 0.310666948557,
#     'met': 0.044346679002,
#     'pop': 0.0620793737471,
#     'reg': 0.0620816536248,
#     'roc': 0.103479810059},
#    'probability': 0.310666948557,
#    'value': 'jaz',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'ismir04_rhythm': {'all': {'ChaChaCha': 0.224528357387,
#     'Jive': 0.14616048336,
#     'Quickstep': 0.0423450283706,
#     'Rumba-American': 0.0518536455929,
#     'Rumba-International': 0.0521722957492,
#     'Rumba-Misc': 0.0627549886703,
#     'Samba': 0.0607895739377,
#     'Tango': 0.216133862734,
#     'VienneseWaltz': 0.124161802232,
#     'Waltz': 0.0190999675542},
#    'probability': 0.224528357387,
#    'value': 'ChaChaCha',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_acoustic': {'all': {'acoustic': 0.383544653654,
#     'not_acoustic': 0.616455316544},
#    'probability': 0.616455316544,
#    'value': 'not_acoustic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_aggressive': {'all': {'aggressive': 0.0510742887855,
#     'not_aggressive': 0.948925733566},
#    'probability': 0.948925733566,
#    'value': 'not_aggressive',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_electronic': {'all': {'electronic': 0.793291330338,
#     'not_electronic': 0.206708669662},
#    'probability': 0.793291330338,
#    'value': 'electronic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_happy': {'all': {'happy': 0.994196236134,
#     'not_happy': 0.0058037750423},
#    'probability': 0.994196236134,
#    'value': 'happy',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_party': {'all': {'not_party': 0.279539525509, 'party': 0.720460474491},
#    'probability': 0.720460474491,
#    'value': 'party',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_relaxed': {'all': {'not_relaxed': 0.392431676388,
#     'relaxed': 0.607568323612},
#    'probability': 0.607568323612,
#    'value': 'relaxed',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_sad': {'all': {'not_sad': 0.543022751808, 'sad': 0.45697721839},
#    'probability': 0.543022751808,
#    'value': 'not_sad',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'moods_mirex': {'all': {'Cluster1': 0.176721170545,
#     'Cluster2': 0.181988254189,
#     'Cluster3': 0.253902345896,
#     'Cluster4': 0.189891308546,
#     'Cluster5': 0.197496905923},
#    'probability': 0.253902345896,
#    'value': 'Cluster3',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'timbre': {'all': {'bright': 0.927759885788, 'dark': 0.0722401440144},
#    'probability': 0.927759885788,
#    'value': 'bright',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'tonal_atonal': {'all': {'atonal': 0.918135225773, 'tonal': 0.081864759326},
#    'probability': 0.918135225773,
#    'value': 'atonal',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'voice_instrumental': {'all': {'instrumental': 0.00494620203972,
#     'voice': 0.995053827763},
#    'probability': 0.995053827763,
#    'value': 'voice',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}}},
#  'metadata': {'audio_properties': {'analysis_sample_rate': 44100,
#    'bit_rate': 256000,
#    'codec': 'mp3',
#    'downmix': 'mix',
#    'equal_loudness': 0,
#    'length': 209.867752075,
#    'lossless': 0,
#    'md5_encoded': '582858e8079bc84e4c00268ae8a5a817',
#    'replay_gain': -14.428319931,
#    'sample_rate': 44100},
#   'tags': {'album': ['Riot on an Empty Street'],
#    'albumartist': ['Kings of Convenience'],
#    'albumartistsort': ['Kings of Convenience'],
#    'artist': ['Kings of Convenience'],
#    'artistsort': ['Kings of Convenience'],
#    'asin': ['B0001W8JP0'],
#    'date': ['2004'],
#    'discnumber': ['1/1'],
#    'file_name': "08-kings_of_convenience-i'd_rather_dance_with_you.mp3",
#    'genre': ['Source'],
#    'language': ['eng'],
#    'musicbrainz album status': ['official'],
#    'musicbrainz album type': ['album'],
#    'musicbrainz_albumartistid': ['cf0f4547-ffbd-4011-98ad-0bec9ba022db'],
#    'musicbrainz_albumid': ['20ed310c-85d6-4c31-b76f-e7285eef5cf4'],
#    'musicbrainz_artistid': ['cf0f4547-ffbd-4011-98ad-0bec9ba022db'],
#    'musicbrainz_recordingid': ['619f63d9-9303-431b-b413-1681b49ae1f7'],
#    'originaldate': ['2004'],
#    'script': ['Latn'],
#    'title': ["I'd Rather Dance With You"],
#    'tracknumber': ['8/11']},
#   'version': {'highlevel': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'},
#    'lowlevel': {'essentia': '2.1-beta2',
#     'essentia_build_sha': '70f2e5ece6736b2c40cc944ad0e695b16b925413',
#     'essentia_git_sha': 'v2.1_beta2',
#     'extractor': 'music 1.0'}}}}

# %%
data['metadata']['version'].keys()
# Out:
# dict_keys(['highlevel', 'lowlevel'])

# %%
#extraxts data for every file in directories
#caution this will take a while
dic = defaultdict(list)
for d in file_list:
        f = open(d)
        data = json.load(f)
        #doesn't collect data if no metadata
        if data.get('metadata') == None:
            continue
        #gets mbid from file title
        temp = d.split('/')[-1].split('-')
        temp.pop(-1);
        id1 = '-'.join(temp)
        #deduplicates mbids by only allowing one id into dictionary
        if id1 in dic['id']:
            continue
        else:
            dic['id'].append(id1)
        #appends new information to dicts
        dic['danceability'].append(data.get('highlevel').get('danceability').get('all').get('danceable'))
        dic['gender_male'].append(data.get('highlevel').get('gender').get('all').get('male'))
        dic['alternative'].append(data.get('highlevel').get('genre_dortmund').get('all').get('alternative'))
        dic['blues'].append(data.get('highlevel').get('genre_dortmund').get('all').get('blues'))
        dic['electronic'].append(data.get('highlevel').get('genre_dortmund').get('all').get('electronic'))
        dic['folkcountry'].append(data.get('highlevel').get('genre_dortmund').get('all').get('folkcountry'))
        dic['funksoulrnb'].append(data.get('highlevel').get('genre_dortmund').get('all').get('funksoulrnb'))
        dic['jazz'].append(data.get('highlevel').get('genre_dortmund').get('all').get('jazz'))
        dic['pop'].append(data.get('highlevel').get('genre_dortmund').get('all').get('pop'))
        dic['raphiphop'].append(data.get('highlevel').get('genre_dortmund').get('all').get('raphiphop'))
        dic['rock'].append(data.get('highlevel').get('genre_dortmund').get('all').get('rock'))
        dic['genre'].append(data.get('highlevel').get('genre_dortmund').get('value'))
        dic['acoustic'].append(data.get('highlevel').get('mood_acoustic').get('all').get('acoustic'))
        dic['aggressive'].append(data.get('highlevel').get('mood_aggressive').get('all').get('aggressive'))
        dic['mood_electronic'].append(data.get('highlevel').get('mood_electronic').get('all').get('electronic'))
        dic['happy'].append(data.get('highlevel').get('mood_happy').get('all').get('happy'))
        dic['party'].append(data.get('highlevel').get('mood_party').get('all').get('party'))
        dic['relaxed'].append(data.get('highlevel').get('mood_relaxed').get('all').get('relaxed'))
        dic['sad'].append(data.get('highlevel').get('mood_sad').get('all').get('sad'))
        dic['mood_mirex_1'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster1'))
        dic['mood_mirex_2'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster2'))
        dic['mood_mirex_3'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster3'))
        dic['mood_mirex_4'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster4'))
        dic['mood_mirex_5'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster5'))
        dic['timbre_bright'].append(data.get('highlevel').get('timbre').get('all').get('bright'))
        dic['tonal'].append(data.get('highlevel').get('tonal_atonal').get('all').get('tonal'))
        dic['instrumental'].append(data.get('highlevel').get('voice_instrumental').get('all').get('instrumental'))
        dic['bit_rate'].append(data.get('metadata').get('audio_properties').get('bit_rate'))
        dic['codec'].append(data.get('metadata').get('audio_properties').get('codec'))
        dic['length'].append(data.get('metadata').get('audio_properties').get('length'))
        dic['lossless'].append(data.get('metadata').get('audio_properties').get('lossless'))
        dic['replay_gain'].append(data.get('metadata').get('audio_properties').get('replay_gain'))
        dic['true_genre'].append(data.get('metadata').get('tags').get('genre'))

        #same with metadata, but metadata in lists so needs an except if the list is empty
        try:
            dic['artist'].append(data.get('metadata').get('tags').get('artist')[0])
        except:
            dic['artist'].append(data.get('metadata').get('tags').get('artist'))       
        try:
            dic['album'].append(data.get('metadata').get('tags').get('album')[0])
        except:
            dic['album'].append(data.get('metadata').get('tags').get('album'))
        try:
            dic['bpm'].append(data.get('metadata').get('tags').get('bpm')[0])
        except:
            dic['bpm'].append(data.get('metadata').get('tags').get('bpm'))
        try:
            dic['year'].append(int(data.get('metadata').get('tags').get('date')[0].split('-')[0]))
        except:
            dic['year'].append(data.get('metadata').get('tags').get('date'))
        try:
            dic['date'].append(data.get('metadata').get('tags').get('date')[0])     
        except:
            dic['date'].append(data.get('metadata').get('tags').get('date'))
        try:
            dic['label'].append(data.get('metadata').get('tags').get('label')[0])
        except:
            dic['label'].append(data.get('metadata').get('tags').get('label'))
        try:
            dic['song'].append(data.get('metadata').get('tags').get('title')[0])
        except:
            dic['song'].append(data.get('metadata').get('tags').get('title'))
        try:
            dic['artistsort'].append(data.get('metadata').get('tags').get('artistsort')[0])
        except:
            dic['artistsort'].append(data.get('metadata').get('tags').get('artistsort'))

# %%
#creates dataframe from dict created
data = pd.DataFrame(dic)

# %%
len(data)
# Out:
# 665

# %%
#number of rows with a value in year
data['year'].count()
# Out:
# 643

# %%
#remove null years
data = data[data['year'].isnull() == False]

# %%
len(data)
# Out:
# 643

# %%
data.head(10)
# Out:
#                                      id  danceability  gender_male  \
# 0  619f63d9-9303-431b-b413-1681b49ae1f7  1.808798e-01     0.654067
# 1  619f60fa-b680-4735-a635-fc0f03715227  8.901892e-01     0.500000
# 2  619632d3-d916-49ad-8ddb-a27fcd0c2bad  3.000001e-14     0.377873
# 3  6192144b-0984-45bb-978a-9bdaa6fa13e9  3.648081e-01     0.888691
# 4  61978cc9-fcd1-4493-8ac7-a523d7853a52  3.000001e-14     0.377873
# 5  619ee3de-edef-4370-9373-02d90b1ccbb7  2.860451e-01     0.905335
# 6  6198c470-0f53-4043-8c96-cc81bee7ae40  9.140623e-01     0.758206
# 7  619d535a-b2b4-4e16-804c-e256f60a0267  3.000001e-14     0.377873
# 8  619aa0ff-588d-4764-a7b8-25d5ec3f287f  4.072887e-02     0.743319
# 9  6192fab3-88fe-4255-8079-f5c515391ce3  3.000001e-14     0.377873
#
#     alternative         blues  electronic  folkcountry   funksoulrnb  \
# 0  1.758280e-02  2.659915e-03    0.967449     0.007424  2.948905e-04
# 1  1.129063e-01  2.394386e-01    0.256372     0.148527  2.319941e-02
# 2  1.878294e-03  1.457041e-04    0.997529     0.000093  4.051082e-06
# 3  2.261784e-02  1.403403e-03    0.968951     0.002974  2.257532e-04
# 4  5.594270e-02  5.800022e-02    0.638596     0.042920  4.798885e-03
# 5  1.313779e-01  1.859132e-01    0.170054     0.189101  1.693741e-02
# 6  9.705611e-04  1.010405e-04    0.998723     0.000096  5.696870e-07
# 7  3.390888e-03  5.241779e-04    0.992979     0.000380  6.315875e-05
# 8  4.779294e-09  5.206847e-09    0.999974     0.000001  1.464147e-07
# 9  7.478595e-04  2.796236e-04    0.996223     0.000335  2.666766e-05
#
#        jazz           pop  ...  replay_gain  \
# 0  0.001406  4.379611e-04  ...   -14.428320
# 1  0.039718  4.216320e-02  ...    -9.880486
# 2  0.000217  1.495819e-05  ...    -5.929924
# 3  0.000455  4.141238e-04  ...   -14.038452
# 4  0.139283  9.367774e-03  ...    -8.160597
# 5  0.024191  4.611452e-02  ...    -7.218739
# 6  0.000030  5.999180e-06  ...   -13.423643
# 7  0.001871  9.144389e-05  ...    -7.973265
# 8  0.000022  5.817790e-08  ...    -3.961552
# 9  0.001979  3.585146e-05  ...    -0.613031
#
#                             true_genre                        artist  \
# 0                             [Source]          Kings of Convenience
# 1            [Classic Rock; Rock; Pop]                   The Beatles
# 2                          [Hard Rock]                  Page & Plant
# 3                                 None           Grand Funk Railroad
# 4                        [Alternative]                     Neko Case
# 5                               [Rock]                          INXS
# 6                                [EBM]                 mind.in.a.box
# 7                               [Rock]                         SCYCS
# 8                         [Soundtrack]           James Newton Howard
# 9  [Modern Folk - Singer / Songwriter]  Crosby, Stills, Nash & Young
#
#                                            album   bpm  year        date  \
# 0                        Riot on an Empty Street  None  2004        2004
# 1                                    Rubber Soul  None  1987  1987-04-30
# 2                        Walking Into Clarksdale  None  1998        1998
# 3  Thirty Years of Funk 1969-1999: The Anthology  None  1999  1999-06-29
# 4                 Fox Confessor Brings the Flood  None  2006        2006
# 5                                           Kick  None  1987  1987-10-20
# 6                                     Crossroads  None  2008  2008-03-04
# 7                         Megahits 99: Die Erste  None  1998        1998
# 8                                   The Fugitive  None  1993        1993
# 9                                   4 Way Street     0  1992  1992-06-23
#
#                 label                                        song  \
# 0                None                   I'd Rather Dance With You
# 1          Parlophone                                What Goes On
# 2            Atlantic                         Upon a Golden Horse
# 3     Capitol Records                                   Crossfire
# 4               ANTI-                             A Widow's Toast
# 5            Atlantic                         Never Tear Us Apart
# 6                None                                    Stalkers
# 7       EMI Electrola                               Next November
# 8  La-La Land Records  Helicopter Chase / The Sewer (Synth Demos)
# 9            Atlantic                      Right Between the Eyes
#
#                      artistsort
# 0          Kings of Convenience
# 1                  Beatles, The
# 2                          None
# 3           Grand Funk Railroad
# 4                    Case, Neko
# 5                          INXS
# 6                          None
# 7                         SCYCS
# 8          Howard, James Newton
# 9  Crosby, Stills, Nash & Young
#
# [10 rows x 42 columns]

# %%
for x in ['lowlevel','tonal','rhythm']:  
    urllib.request.urlretrieve(f"https://data.metabrainz.org/pub/musicbrainz/acousticbrainz/dumps/acousticbrainz-lowlevel-features-20220623/acousticbrainz-lowlevel-features-20220623-{x}.tar.zst"
                           ,f"/Users/ryanlnewbury/Downloads/acousticbrainz-lowlevel-features-20220623-{x}.tar.zst")
    path_to_zst = f"/Users/ryanlnewbury/Downloads/acousticbrainz-lowlevel-features-20220623-{x}.tar.zst"
    path_to_zst_extract = "/Users/ryanlnewbury/Downloads"
    extract_zst(path_to_zst,
                path_to_zst_extract)

# %%
#loads features extracted from acousticbrainz lowlevel features, from 3 different csvs on their website
lowlevel = pd.read_csv("/Users/ryanlnewbury/Downloads/acousticbrainz-lowlevel-features-20220623/acousticbrainz-lowlevel-features-20220623-lowlevel.csv")
rhythm = pd.read_csv("/Users/ryanlnewbury/Downloads/acousticbrainz-lowlevel-features-20220623/acousticbrainz-lowlevel-features-20220623-rhythm.csv")
tonal = pd.read_csv("/Users/ryanlnewbury/Downloads/acousticbrainz-lowlevel-features-20220623/acousticbrainz-lowlevel-features-20220623-tonal.csv")

# %%
lowlevel.head(10)
# Out:
#                                    mbid  submission_offset  average_loudness  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0          0.703280
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0          0.657434
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0          0.228847
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0          0.328406
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0          0.570070
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0          0.168545
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0          0.854816
# 7  19084069-642f-465f-9127-f71bcd800a05                  0          0.030876
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0          0.925762
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0          0.475052
#
#    dynamic_complexity  mfcc_zero_mean
# 0            5.612967     -722.370972
# 1            5.046805     -690.498535
# 2            5.314451     -706.800476
# 3            4.475980     -721.950439
# 4            9.305593     -784.208496
# 5            9.074841     -792.645020
# 6            2.146111     -652.554626
# 7            3.557840     -749.831482
# 8            2.719668     -646.503784
# 9            5.929364     -682.161255

# %%
rhythm.head(10)
# Out:
#                                    mbid  submission_offset         bpm  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0  120.763885
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0  125.956993
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0  132.617203
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0  144.318924
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0  128.347702
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0  120.360603
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0  151.575623
# 7  19084069-642f-465f-9127-f71bcd800a05                  0   82.642754
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0  129.358032
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0   91.101822
#
#    bpm_histogram_first_peak_bpm_mean  bpm_histogram_first_peak_bpm_median  \
# 0                              120.0                                120.0
# 1                              126.0                                126.0
# 2                              133.0                                133.0
# 3                              144.0                                144.0
# 4                              129.0                                129.0
# 5                              120.0                                120.0
# 6                              152.0                                152.0
# 7                               82.0                                 82.0
# 8                              129.0                                129.0
# 9                               91.0                                 91.0
#
#    bpm_histogram_second_peak_bpm_mean  bpm_histogram_second_peak_bpm_median  \
# 0                               133.0                                 133.0
# 1                               136.0                                 136.0
# 2                               140.0                                 140.0
# 3                               152.0                                 152.0
# 4                               120.0                                 120.0
# 5                               115.0                                 115.0
# 6                               157.0                                 157.0
# 7                                94.0                                  94.0
# 8                               123.0                                 123.0
# 9                               172.0                                 172.0
#
#    danceability  onset_rate
# 0      0.996203    2.867577
# 1      1.131311    3.568778
# 2      0.915099    2.858371
# 3      0.972823    2.395773
# 4      1.102882    2.419718
# 5      0.974217    1.876432
# 6      1.139013    3.394924
# 7      0.872103    5.799162
# 8      1.155036    3.361048
# 9      1.073015    2.519788

# %%
tonal.head(10)
# Out:
#                                    mbid  submission_offset key_key key_scale  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0       A     major
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0       A     major
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0       G     major
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0       D     major
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0       A     minor
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0       G     minor
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0       G     major
# 7  19084069-642f-465f-9127-f71bcd800a05                  0       D     minor
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0       E     major
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0       A     major
#
#    tuning_frequency  tuning_equal_tempered_deviation
# 0        434.193115                         0.141634
# 1        434.193115                         0.177662
# 2        434.193115                         0.234276
# 3        434.193115                         0.219335
# 4        434.193115                         0.164615
# 5        442.548920                         0.000000
# 6        434.193115                         0.224572
# 7        434.193115                         0.195417
# 8        445.112549                         0.095341
# 9        444.598633                         0.032828

# %%
#length of the 3 csv files
len(rhythm)
# Out:
# 29460584

# %%
len(tonal)
# Out:
# 29460584

# %%
len(lowlevel)
# Out:
# 29460584

# %%
#number of unique ids in csvs
rhythm['mbid'].nunique()
# Out:
# 7564215

# %%
tonal['mbid'].nunique()
# Out:
# 7564215

# %%
lowlevel['mbid'].nunique()
# Out:
# 7564215

# %%
#dropping duplicates from csvs
rhythm = rhythm.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(rhythm)
# Out:
# 7564215

# %%
tonal = tonal.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(tonal)
# Out:
# 7564215

# %%
lowlevel = lowlevel.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(lowlevel)
# Out:
# 7564215

# %%
#joining all data into one dataframe
data1 = data.set_index('id').join(rhythm.set_index('mbid'),how = 'left',rsuffix = '_2')

# %%
data2 = data1.join(tonal.set_index('mbid'),how = 'left', rsuffix = '_2')

# %%
data3 = data2.join(lowlevel.set_index('mbid'),how = 'left', rsuffix = '_2')

# %%
data3.head(10)
# Out:
#                                       danceability  gender_male   alternative  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7  1.808798e-01     0.654067  1.758280e-02
# 619f60fa-b680-4735-a635-fc0f03715227  8.901892e-01     0.500000  1.129063e-01
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad  3.000001e-14     0.377873  1.878294e-03
# 6192144b-0984-45bb-978a-9bdaa6fa13e9  3.648081e-01     0.888691  2.261784e-02
# 61978cc9-fcd1-4493-8ac7-a523d7853a52  3.000001e-14     0.377873  5.594270e-02
# 619ee3de-edef-4370-9373-02d90b1ccbb7  2.860451e-01     0.905335  1.313779e-01
# 6198c470-0f53-4043-8c96-cc81bee7ae40  9.140623e-01     0.758206  9.705611e-04
# 619d535a-b2b4-4e16-804c-e256f60a0267  3.000001e-14     0.377873  3.390888e-03
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f  4.072887e-02     0.743319  4.779294e-09
# 6192fab3-88fe-4255-8079-f5c515391ce3  3.000001e-14     0.377873  7.478595e-04
#
#                                              blues  electronic  folkcountry  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7  2.659915e-03    0.967449     0.007424
# 619f60fa-b680-4735-a635-fc0f03715227  2.394386e-01    0.256372     0.148527
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad  1.457041e-04    0.997529     0.000093
# 6192144b-0984-45bb-978a-9bdaa6fa13e9  1.403403e-03    0.968951     0.002974
# 61978cc9-fcd1-4493-8ac7-a523d7853a52  5.800022e-02    0.638596     0.042920
# 619ee3de-edef-4370-9373-02d90b1ccbb7  1.859132e-01    0.170054     0.189101
# 6198c470-0f53-4043-8c96-cc81bee7ae40  1.010405e-04    0.998723     0.000096
# 619d535a-b2b4-4e16-804c-e256f60a0267  5.241779e-04    0.992979     0.000380
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f  5.206847e-09    0.999974     0.000001
# 6192fab3-88fe-4255-8079-f5c515391ce3  2.796236e-04    0.996223     0.000335
#
#                                        funksoulrnb      jazz           pop  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7  2.948905e-04  0.001406  4.379611e-04
# 619f60fa-b680-4735-a635-fc0f03715227  2.319941e-02  0.039718  4.216320e-02
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad  4.051082e-06  0.000217  1.495819e-05
# 6192144b-0984-45bb-978a-9bdaa6fa13e9  2.257532e-04  0.000455  4.141238e-04
# 61978cc9-fcd1-4493-8ac7-a523d7853a52  4.798885e-03  0.139283  9.367774e-03
# 619ee3de-edef-4370-9373-02d90b1ccbb7  1.693741e-02  0.024191  4.611452e-02
# 6198c470-0f53-4043-8c96-cc81bee7ae40  5.696870e-07  0.000030  5.999180e-06
# 619d535a-b2b4-4e16-804c-e256f60a0267  6.315875e-05  0.001871  9.144389e-05
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f  1.464147e-07  0.000022  5.817790e-08
# 6192fab3-88fe-4255-8079-f5c515391ce3  2.666766e-05  0.001979  3.585146e-05
#
#                                          raphiphop  ...  onset_rate  \
# id                                                  ...
# 619f63d9-9303-431b-b413-1681b49ae1f7  1.125043e-04  ...    4.326175
# 619f60fa-b680-4735-a635-fc0f03715227  1.680163e-02  ...    5.457075
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad  5.780928e-06  ...    2.130402
# 6192144b-0984-45bb-978a-9bdaa6fa13e9  1.731058e-04  ...    3.034324
# 61978cc9-fcd1-4493-8ac7-a523d7853a52  6.285998e-03  ...    2.792825
# 619ee3de-edef-4370-9373-02d90b1ccbb7  1.146711e-02  ...    2.844084
# 6198c470-0f53-4043-8c96-cc81bee7ae40  4.613626e-07  ...    4.612633
# 619d535a-b2b4-4e16-804c-e256f60a0267  3.622894e-05  ...    2.691104
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f  1.890420e-08  ...    2.228352
# 6192fab3-88fe-4255-8079-f5c515391ce3  8.066453e-06  ...    2.371305
#
#                                       submission_offset_2  key_key  key_scale  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7                    0       D#      major
# 619f60fa-b680-4735-a635-fc0f03715227                    0        A      minor
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad                    0       A#      minor
# 6192144b-0984-45bb-978a-9bdaa6fa13e9                    0        D      major
# 61978cc9-fcd1-4493-8ac7-a523d7853a52                    0        F      minor
# 619ee3de-edef-4370-9373-02d90b1ccbb7                    0        F      major
# 6198c470-0f53-4043-8c96-cc81bee7ae40                    0        B      minor
# 619d535a-b2b4-4e16-804c-e256f60a0267                    0        F      minor
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f                    0        G      major
# 6192fab3-88fe-4255-8079-f5c515391ce3                    0        F      minor
#
#                                       tuning_frequency  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7        440.508575
# 619f60fa-b680-4735-a635-fc0f03715227        434.193115
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad        434.193115
# 6192144b-0984-45bb-978a-9bdaa6fa13e9        434.193115
# 61978cc9-fcd1-4493-8ac7-a523d7853a52        447.174194
# 619ee3de-edef-4370-9373-02d90b1ccbb7        438.224518
# 6198c470-0f53-4043-8c96-cc81bee7ae40        440.000000
# 619d535a-b2b4-4e16-804c-e256f60a0267        434.193115
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f        442.804626
# 6192fab3-88fe-4255-8079-f5c515391ce3        434.193115
#
#                                       tuning_equal_tempered_deviation  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7                         0.020504
# 619f60fa-b680-4735-a635-fc0f03715227                         0.208812
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad                         0.187084
# 6192144b-0984-45bb-978a-9bdaa6fa13e9                         0.201451
# 61978cc9-fcd1-4493-8ac7-a523d7853a52                         0.229774
# 619ee3de-edef-4370-9373-02d90b1ccbb7                         0.086532
# 6198c470-0f53-4043-8c96-cc81bee7ae40                         0.012354
# 619d535a-b2b4-4e16-804c-e256f60a0267                         0.188965
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f                         0.072889
# 6192fab3-88fe-4255-8079-f5c515391ce3                         0.188651
#
#                                       submission_offset_2  average_loudness  \
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7                    0          0.927267
# 619f60fa-b680-4735-a635-fc0f03715227                    0          0.905077
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad                    0          0.757508
# 6192144b-0984-45bb-978a-9bdaa6fa13e9                    0          0.934868
# 61978cc9-fcd1-4493-8ac7-a523d7853a52                    0          0.639869
# 619ee3de-edef-4370-9373-02d90b1ccbb7                    0          0.687216
# 6198c470-0f53-4043-8c96-cc81bee7ae40                    0          0.856200
# 619d535a-b2b4-4e16-804c-e256f60a0267                    0          0.619785
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f                    0          0.104274
# 6192fab3-88fe-4255-8079-f5c515391ce3                    0          0.011282
#
#                                       dynamic_complexity  mfcc_zero_mean
# id
# 619f63d9-9303-431b-b413-1681b49ae1f7            3.180683     -682.701538
# 619f60fa-b680-4735-a635-fc0f03715227            3.672358     -654.275208
# 619632d3-d916-49ad-8ddb-a27fcd0c2bad            2.402322     -658.484436
# 6192144b-0984-45bb-978a-9bdaa6fa13e9            2.966868     -638.990540
# 61978cc9-fcd1-4493-8ac7-a523d7853a52            5.109163     -762.092285
# 619ee3de-edef-4370-9373-02d90b1ccbb7            5.789335     -678.900818
# 6198c470-0f53-4043-8c96-cc81bee7ae40            4.853683     -677.775269
# 619d535a-b2b4-4e16-804c-e256f60a0267            6.166994     -697.542725
# 619aa0ff-588d-4764-a7b8-25d5ec3f287f            6.579127     -749.649902
# 6192fab3-88fe-4255-8079-f5c515391ce3            7.226090     -767.877686
#
# [10 rows x 58 columns]

# %%
data3.to_parquet('data.parquet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data3.to_parquet('data.parquet')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:2976, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2889 """
#    2890 Write a DataFrame to the binary parquet format.
#    2891
#    (...)
#    2972 >>> content = f.read()
#    2973 """
#    2974 from pandas.io.parquet import to_parquet
# -> 2976 return to_parquet(
#    2977     self,
#    2978     path,
#    2979     engine,
#    2980     compression=compression,
#    2981     index=index,
#    2982     partition_cols=partition_cols,
#    2983     storage_options=storage_options,
#    2984     **kwargs,
#    2985 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:430, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     426 impl = get_engine(engine)
#     428 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 430 impl.write(
#     431     df,
#     432     path_or_buf,
#     433     compression=compression,
#     434     index=index,
#     435     partition_cols=partition_cols,
#     436     storage_options=storage_options,
#     437     **kwargs,
#     438 )
#     440 if path is None:
#     441     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:174, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, **kwargs)
#     171 if index is not None:
#     172     from_pandas_kwargs["preserve_index"] = index
# --> 174 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     176 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     177     path,
#     178     kwargs.pop("filesystem", None),
#    (...)
#     181     is_dir=partition_cols is not None,
#     182 )
#     183 if (
#     184     isinstance(path_or_handle, io.BufferedWriter)
#     185     and hasattr(path_or_handle, "name")
#     186     and isinstance(path_or_handle.name, (str, bytes))
#     187 ):
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/table.pxi:3557, in pyarrow.lib.Table.from_pandas()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:570, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     562 def dataframe_to_arrays(df, schema, preserve_index, nthreads=1, columns=None,
#     563                         safe=True):
#     564     (all_names,
#     565      column_names,
#     566      index_column_names,
#     567      index_descriptors,
#     568      index_columns,
#     569      columns_to_convert,
# --> 570      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
#     571                                                columns)
#     573     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#     574     # using a thread pool is worth it. Currently the heuristic is whether the
#     575     # nrows > 100 * ncols and ncols > 1.
#     576     if nthreads is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:352, in _get_columns_to_convert(df, schema, preserve_index, columns)
#     349 columns = _resolve_columns_of_interest(df, schema, columns)
#     351 if not df.columns.is_unique:
# --> 352     raise ValueError(
#     353         'Duplicate column names found: {}'.format(list(df.columns))
#     354     )
#     356 if schema is not None:
#     357     return _get_columns_to_convert_given_schema(df, schema, preserve_index)
#
# ValueError: Duplicate column names found: ['danceability', 'gender_male', 'alternative', 'blues', 'electronic', 'folkcountry', 'funksoulrnb', 'jazz', 'pop', 'raphiphop', 'rock', 'genre', 'acoustic', 'aggressive', 'mood_electronic', 'happy', 'party', 'relaxed', 'sad', 'mood_mirex_1', 'mood_mirex_2', 'mood_mirex_3', 'mood_mirex_4', 'mood_mirex_5', 'timbre_bright', 'tonal', 'instrumental', 'bit_rate', 'codec', 'length', 'lossless', 'replay_gain', 'true_genre', 'artist', 'album', 'bpm', 'year', 'date', 'label', 'song', 'artistsort', 'submission_offset', 'bpm_2', 'bpm_histogram_first_peak_bpm_mean', 'bpm_histogram_first_peak_bpm_median', 'bpm_histogram_second_peak_bpm_mean', 'bpm_histogram_second_peak_bpm_median', 'danceability_2', 'onset_rate', 'submission_offset_2', 'key_key', 'key_scale', 'tuning_frequency', 'tuning_equal_tempered_deviation', 'submission_offset_2', 'average_loudness', 'dynamic_complexity', 'mfcc_zero_mean']
